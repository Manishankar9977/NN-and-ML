# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9d08bebe-1373-4ead-9853-9b6d58695bcc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d08bebe-1373-4ead-9853-9b6d58695bcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pima-indians-diabetes.csv to pima-indians-diabetes.csv

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("pima-indians-diabetes.csv",header=None)
df
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# (note: Dense implements the operation: output
# = activation(dot(input, kernel) + bias) where
# activation is the element-wise activation function
# passed as the activation argument, kernel is a weights
# matrix created by the layer, and bias is a bias vector
# created by the layer (only applicable if use_bias is
# True).

# %%
dataset=loadtxt('pima-indians-diabetes.csv',delimiter=',')
x=dataset[:,0:8]
y=dataset[:,8]

# %% [markdown]
# Models in Keras are defined as a sequence of layers.
# Design a fully-connected network structure with three layers.
#
# Fully connected layers are defined using the Dense class. We can specify the
# number of neurons or nodes in the layer as the first argument, and specify the
# activation function using the activation argument.
#
# We will use the rectified linear unit activation referred to as ReLU on the first
# two layers and the Sigmoid function in the output layer.

# %%
model= Sequential()
model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %% [markdown]
# Compile the Keras model
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or
# TensorFlow..
# We must specify the loss function to use to evaluate a set of weights, the optimizer is used to search through different weights for
# the network and any optional metrics we would like to collect and report during training.
# In this case, we will use cross entropy as the loss argument. This loss is for a binary classification problems and is defined in
# Keras as “binary_crossentropy“. You can learn more about choosing loss functions based on your problem here:
#
# #
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm
# “adam“. This is a popular version of gradient descent because it automatically tunes itself
# and gives good results in a wide range of problems.

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# Epoch: One pass through all of the rows in the training dataset.
#
# Batch: One or more samples considered by the model within an epoch before
# weights are updated.

# %%
model.fit(x, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 77/77 [==============================] - 1s 2ms/step - loss: 1.5914 - accuracy: 0.6224
# Epoch 2/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8395 - accuracy: 0.5924
# Epoch 3/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8306 - accuracy: 0.6081
# Epoch 4/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7869 - accuracy: 0.6055
# Epoch 5/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7695 - accuracy: 0.6224
# Epoch 6/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7364 - accuracy: 0.6211
# Epoch 7/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7327 - accuracy: 0.6263
# Epoch 8/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7099 - accuracy: 0.6289
# Epoch 9/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.6367
# Epoch 10/200
# ...

# %%
#evaluate the keras model
_,accuracy = model.evaluate(x,y)
print('Accuracy : %.2f'% (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 937us/step - loss: 0.5034 - accuracy: 0.7135
# Accuracy : 71.35

# %%
# make probability predictions with the model
from numpy import array
Xp = array([[6.0, 158.0, 72.0, 35.0, 0.0, 55.5, 0.627, 50.0]])
Yp = model.predict(Xp)
print(Xp[0],Yp[0])
# Out:
# [  6.    158.     72.     35.      0.     55.5     0.627  50.   ] [0.4547523]
