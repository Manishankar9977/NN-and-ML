# %%
# !pip install -U pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting pillow
#   Downloading Pillow-9.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 25.6 MB/s

# %%
import PIL
from PIL import Image

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-3c3c0370-7511-4ec3-aaa9-31a442560020" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c3c0370-7511-4ec3-aaa9-31a442560020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG_8702.JPG to IMG_8702.JPG

# %%
img=Image.open('/content/IMG_8702.JPG')
print(img.mode)
print(img.format)
print(img.size)
# Out:
# RGB
# JPEG
# (5184, 3456)

# %%
img

# %%
gs_img=img.convert(mode='L')
gs_img

# %% [markdown]
# UPLOADING IMAGE WITH MATPLOTLIB

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
data=image.imread('/content/IMG_8702.JPG')
print(data.dtype)
print(data.shape)
pyplot.imshow(data)
# Out:
# uint8
# (3456, 5184, 3)

# %%
data
# Out:
# array([[[203, 198, 194],
#         [203, 198, 194],
#         [208, 205, 200],
#         ...,
#         [ 29,  33,  34],
#         [ 31,  35,  36],
#         [ 31,  35,  36]],
#
#        [[200, 195, 191],
#         [204, 199, 195],
#         [206, 201, 197],
#         ...,
#         [ 28,  32,  33],
#         [ 29,  33,  34],
#         [ 30,  34,  35]],
#
#        [[201, 196, 193],
#         [201, 196, 193],
#         [202, 197, 194],
#         ...,
#         [ 29,  33,  34],
#         [ 29,  33,  34],
#         [ 30,  34,  35]],
#
#        ...,
#
#        [[167, 173, 163],
#         [164, 172, 161],
#         [165, 173, 160],
#         ...,
#         [ 34,  36,  35],
#         [ 35,  37,  36],
#         [ 38,  38,  38]],
#
#        [[167, 170, 161],
#         [167, 170, 161],
#         [165, 171, 159],
#         ...,
#         [ 36,  38,  37],
#         [ 35,  37,  36],
#         [ 38,  40,  39]],
#
#        [[165, 166, 158],
#         [166, 169, 158],
#         [166, 169, 158],
#         ...,
#         [ 36,  38,  37],
#         [ 35,  37,  36],
#         [ 37,  39,  38]]], dtype=uint8)

# %%
from numpy import asarray
data1=asarray(img)
print(data1)
print(data1.shape)
# Out:
# [[[203 198 194]
#   [203 198 194]
#   [208 205 200]
#   ...
#   [ 29  33  34]
#   [ 31  35  36]
#   [ 31  35  36]]
#
#  [[200 195 191]
#   [204 199 195]
#   [206 201 197]
#   ...
#   [ 28  32  33]
#   [ 29  33  34]
#   [ 30  34  35]]
#
#  [[201 196 193]
#   [201 196 193]
#   [202 197 194]
#   ...
#   [ 29  33  34]
#   [ 29  33  34]
#   [ 30  34  35]]
#
#  ...
#
#  [[167 173 163]
#   [164 172 161]
#   [165 173 160]
#   ...
#   [ 34  36  35]
#   [ 35  37  36]
#   [ 38  38  38]]
#
#  [[167 170 161]
#   [167 170 161]
#   [165 171 159]
#   ...
#   [ 36  38  37]
#   [ 35  37  36]
#   [ 38  40  39]]
#
#  [[165 166 158]
#   [166 169 158]
#   [166 169 158]
#   ...
#   [ 36  38  37]
#   [ 35  37  36]
#   [ 37  39  38]]]
# (3456, 5184, 3)
